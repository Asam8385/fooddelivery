# %%
# Load the extension
# %load_ext sql

# Connect with Windows Authentication
# %sql mssql+pyodbc://localhost/master?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes

# %%
# confilicting with sql lib so make sure to install prettytable 2.5.0
import prettytable
print(prettytable.__version__)
# Out:
# 2.5.0

# %%
# %%sql
# SELECT TOP 1 * FROM sysobjects
# Out:
# [('sp_MSalreadyhavegeneration', -1073624922, 'P ', 4, 0, 0, 0, 0, 0, datetime.datetime(2022, 10, 8, 6, 30, 1, 120000), 0, 0, 0, 'P ', 0, 4, 0, datetime.datetime(2022, 10, 8, 6, 30, 1, 120000), 0, 0, 0, 0, 0, 2, 0)]

# %%
# remove unwanted output
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %%sql
# SELECT TOP 10 * FROM sysobjects
# Out:
# [('sp_MSalreadyhavegeneration', -1073624922, 'P ', 4, 0, 0, 0, 0, 0, datetime.datetime(2022, 10, 8, 6, 30, 1, 120000), 0, 0, 0, 'P ', 0, 4, 0, datetime.datetime(2022, 10, 8, 6, 30, 1, 120000), 0, 0, 0, 0, 0, 2, 0),
#  ('sp_MSwritemergeperfcounter', -1072815163, 'P ', 4, 0, 0, 0, 0, 0, datetime.datetime(2022, 10, 8, 6, 29, 51, 120000), 0, 0, 0, 'P ', 0, 4, 0, datetime.datetime(2022, 10, 8, 6, 29, 51, 120000), 0, 0, 0, 0, 0, 2, 0),
#  ('sp_drop_trusted_assembly', -1072667163, 'X ', 4, 0, 0, 0, 0, 0, datetime.datetime(2022, 10, 8, 6, 28, 55, 853000), 0, 0, 0, 'X ', 0, 4, 0, datetime.datetime(2022, 10, 8, 6, 28, 55, 853000), 0, 0, 0, 0, 0, 2, 0),
#  ('TABLE_PRIVILEGES', -1072372588, 'V ', 3, 0, 0, 0, 0, 0, datetime.datetime(2022, 10, 8, 6, 29, 36, 927000), 0, 0, 0, 'V ', 0, 2, 0, datetime.datetime(2022, 10, 8, 6, 29, 36, 927000), 0, 0, 0, 0, 0, 2, 0),
# ...

# %%
# here we go with out food devivery app implemenation
