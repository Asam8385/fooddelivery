# %%
# Load the extension
# %load_ext sql

# Connect with Windows Authentication(c++ ODBC Driver 17 for SQL Server)
# %sql mssql+pyodbc://localhost/master?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes

# %%
# confilicting with sql lib so make sure to install prettytable 2.5.0
import prettytable
print(prettytable.__version__)

# %%
# %%sql
# SELECT TOP 1 * FROM sysobjects

# %%
# remove unwanted output
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %%sql
# SELECT TOP 10 * FROM sysobjects

# %%
# here we  with out food devivery app implemenation
'''
i am ing to list down the entites

name of the database: FoodDeliveryApp

shema: 
1. production 
2. testing

for this session we are not ing to talk about the production schema...

entities:

1. Customer
2. Restaurant
3. Menu
4. FoodItem
5. Order
6. OrderItem
7. DeliveryPerson
8. Payment

relationships:

1. A Customer can place multiple Orders.
2. An Order is associated with one Customer.
3. A Restaurant can have multiple Menus.
4. A Menu belongs to one Restaurant.
5. A Menu can have multiple FoodItems.
6. A FoodItem belongs to one Menu.
7. An Order can have multiple OrderItems.
8. An OrderItem is associated with one Order and one FoodItem.
9. A DeliveryPerson can deliver multiple Orders.
10. An Order is delivered by one DeliveryPerson.
11. A Payment is associated with one Order.
12. An Order can have one Payment.




'''
